# %% [markdown]
# <a href="https://colab.research.google.com/github/vane-2005/progra_python/blob/main/2023_2s_Desaf%C3%ADos_de_programaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Desafíos de programación**
#
# Para cada uno de los siguientes desafíos, elabora:
#
# 1. La tabla de datos y variables.
# 1. El diagrama de flujo.
# 1. El programa en Python (sin validaciones).
#
# > Por **sin validaciones** me refiero a que los programas asumen un _happy path_, es decir, se capturan los datos ideales para que funcione. En las pruebas se capturan puros datos válidos, y no es necesario codificar para evitar el uso de datos incorrectos.

# %% [markdown]
# ---
#
# La **tabla de datos y variables** debe contener las siguientes columnas:
#
# |Dato|Datatype|Origen|Variables|Fórmulas|
# |---|---|---|---|---|
# |Dato|Datatype|Origen|Variables|Fórmulas|

# %% [markdown]
# ---
#
# Para el **diagrama de flujo**, usar esta simbología.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Programa 1: Suma
#
# Elabora un programa que pregunte dos números, y que muestre la suma de los dos.

# %% [markdown]
# # Programa 2: Círculo
#
# El área de un círculo se calcula con la siguiente fórmula:
#
# ```
# a=PI*(radio*radio)
# ```
#
# Haz un programa que pregunte el ``radio`` y que muestre el área del círculo.

# %% [markdown]
# # Programa 3: Cambio de divisas
#
# Elabora un programa que pregunte el tipo de cambio MXN-USD, que pregunte una cantidad en dólares, y que convierta los dólares a pesos.

# %% [markdown]
# # Programa 4: Mayor y menor
#
# Elabora un programa que pregunte dos números, y de diga cuál es el mayor, cuál es el menor, o si son iguales.

# %% [markdown]
# # Programa 5: Monto acumulado
#
# Elabora un programa que pregunte una cantidad indeterminada de números, y que al final, muestre la suma acumulada de los mismos.
#
# El programa deberá preguntar números hasta que se deje vacía la captura, lo que indica que ya debe parar la captura.
